# %%
import os
import uuid
from pathlib import Path
from ray.job_submission import JobSubmissionClient

# Use the same dashboard address pattern as thor_ray_job_test.ipynb
RAY_DASHBOARD_ADDRESS = os.environ.get(
    "RAY_DASHBOARD_ADDRESS",
    "http://34.118.238.105:8265",  # same default you use elsewhere
)

REPO_ROOT = Path("..").resolve()
print(f"Using repo root as working_dir: {REPO_ROOT}")

client = JobSubmissionClient(RAY_DASHBOARD_ADDRESS)
print(f"Connected to Ray Dashboard at {RAY_DASHBOARD_ADDRESS}, version: {client.get_version()}")

# %%
# Make faster

# update to use ray

# update to use big query 

# put ananlysis observations in big query 

# figure out where to store the results - as a table?
