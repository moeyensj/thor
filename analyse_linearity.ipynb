# %%
from google.cloud import bigquery

# Adjust these placeholders to match your environment
PROJECT_ID = "my-project"
DATASET_ID = "recovered_observations_dataset"
TABLE_ID = "recovered_observations"

client = bigquery.Client(project=PROJECT_ID)

query = f"""
SELECT *
FROM `{PROJECT_ID}.{DATASET_ID}.{TABLE_ID}`
"""

recovered_observations_df = client.query(query).to_dataframe()
recovered_observations_df.head()

# %%
#for each test orbit, group observations with the same orbit id  
# keep the objects with more than 6 observations

# %%
# for each of these, determine how linear the observations are
